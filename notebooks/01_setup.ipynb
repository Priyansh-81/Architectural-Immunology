# %%
import sys
import torch

print(sys.executable)
print(torch.__version__)
# Out:
# /usr/bin/python3
# 2.11.0+cu128

# %%
import os

if "COLAB_GPU" in os.environ:
    # !git clone https://github.com/Priyansh-81/Architectural-Immunology.git
    # %cd Architectural-Immunology
else:
    print("Running locally — repo already available")
# Out:
# Cloning into 'Architectural-Immunology'...
# remote: Enumerating objects: 44, done.
# remote: Counting objects: 100% (44/44), done.
# remote: Compressing objects: 100% (36/36), done.
# remote: Total 44 (delta 11), reused 40 (delta 7), pack-reused 0 (from 0)
# Receiving objects: 100% (44/44), 16.62 KiB | 3.32 MiB/s, done.
# Resolving deltas: 100% (11/11), done.
# /content/Architectural-Immunology

# %%
import os

if "COLAB_GPU" in os.environ:
    # !pip install -U transformers accelerate bitsandbytes sentencepiece datasets
else:
    print("Using local environment packages")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 100.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 13.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 555.1/555.1 kB 49.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 MB 19.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 18.1.0
#     Uninstalling pyarrow-18.1.0:
#       Successfully uninstalled pyarrow-18.1.0
#   Attempting uninstall: datasets
#     Found existing installation: datasets 4.0.0
#     Uninstalling datasets-4.0.0:
#       Successfully uninstalled datasets-4.0.0
#   Attempting uninstall: transformers
#     Found existing installation: transformers 5.12.0
#     Uninstalling transformers-5.12.0:
#       Successfully uninstalled transformers-5.12.0
# ...

# %%
import torch

print("CUDA:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
elif hasattr(torch.backends, "mps") and torch.backends.mps.is_available():
    print("Apple Silicon GPU (MPS) available")
else:
    print("CPU only")
# Out:
# CUDA: True
# GPU: Tesla T4

# %%
import os
from getpass import getpass

token = getpass("HuggingFace Token (optional): ")

if token:
    os.environ["HF_TOKEN"] = token
    print("Token loaded")
else:
    print("Continuing without token")
# Out:
# HuggingFace Token (optional): ··········
# Token loaded

# %%
from src.config import CONFIG
print(CONFIG)
# Out:
# AppConfig(model=ModelConfig(small_model='Qwen/Qwen2.5-1.5B-Instruct', reasoning_model='microsoft/Phi-3-mini-4k-instruct', quantized=True, use_flash_attention=False, device='auto', max_new_tokens=256, temperature=0.7), drift=DriftConfig(entropy_threshold=3.0, perplexity_threshold=50.0, tool_oscillation_threshold=0.4, context_pollution_threshold=0.35, intervention_threshold=0.7), eval=EvaluationConfig(max_steps_per_task=25, rolling_window=10, save_logs=True), paths=Paths(root=PosixPath('.'), data_dir=PosixPath('data'), logs_dir=PosixPath('outputs/logs'), plots_dir=PosixPath('outputs/plots')))

# %%
print("Setup complete")
# Out:
# Setup complete
