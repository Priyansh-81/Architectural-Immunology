# %%
import sys
import torch

print(sys.executable)
print(torch.__version__)
# Out:
# /Users/priyanshnandan/Library/Mobile Documents/com~apple~CloudDocs/Codes/DriftProject/venv/bin/python
# 2.12.1

# %%
import os

if "COLAB_GPU" in os.environ:
    # !git clone https://github.com/Priyansh-81/Architectural-Immunology.git
    # %cd Architectural-Immunology
else:
    print("Running locally — repo already available")
# Out:
# Running locally — repo already available

# %%
import os

if "COLAB_GPU" in os.environ:
    # !pip install -U transformers accelerate bitsandbytes sentencepiece datasets
else:
    print("Using local environment packages")
# Out:
# Using local environment packages

# %%
import torch

print("CUDA:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
elif hasattr(torch.backends, "mps") and torch.backends.mps.is_available():
    print("Apple Silicon GPU (MPS) available")
else:
    print("CPU only")
# Out:
# CUDA: False
# Apple Silicon GPU (MPS) available

# %%
import os
from getpass import getpass

token = getpass("HuggingFace Token (optional): ")

if token:
    os.environ["HF_TOKEN"] = token
    print("Token loaded")
else:
    print("Continuing without token")

# %%
from src.config import CONFIG
print(CONFIG)

# %%
print("Setup complete")
